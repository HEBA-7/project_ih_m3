# %%
#Import your libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import matplotlib.pylab as plt
import functools as ft

from sklearn import datasets
from sklearn.datasets import make_regression
from sklearn.model_selection import train_test_split
import pickle
import joblib

from sklearn import linear_model
from sklearn.linear_model import ElasticNet
from sklearn.linear_model import Ridge
from sklearn.svm import SVR
from sklearn.linear_model import SGDRegressor
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error
from sklearn.ensemble import RandomForestRegressor
from sklearn.preprocessing import RobustScaler, StandardScaler, MinMaxScaler
from sklearn.preprocessing import OneHotEncoder, OrdinalEncoder
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import roc_auc_score
from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import RandomizedSearchCV
from sklearn.ensemble import GradientBoostingRegressor
from sklearn.model_selection import cross_val_score

# %% [markdown]
# ### Exploración de los datos

# %%
#importamos todos los datos

di_city = pd.read_csv("./data/diamonds_city_202208201409.csv", keep_default_na=False, na_values=[""])
di_clarity = pd.read_csv("./data/diamonds_clarity_202208201409.csv", keep_default_na=False, na_values=[""])
di_color = pd.read_csv("./data/diamonds_color_202208201409.csv", keep_default_na=False, na_values=[""])
di_cut = pd.read_csv("./data/diamonds_cut_202208201409.csv", keep_default_na=False, na_values=[""])
di_dime = pd.read_csv("./data/diamonds_dimensions_202208201409.csv", keep_default_na=False, na_values=[""])
di_prop = pd.read_csv("./data/diamonds_properties_202208201409.csv", keep_default_na=False, na_values=[""])
di_trans = pd.read_csv("./data/diamonds_transactional_202208201409.csv", keep_default_na=False, na_values=[""])

# %%
#vemos cómo son y la información que trae cada tabala- esta es de las ciudades
di_city.info()
di_city
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13 entries, 0 to 12
# Data columns (total 2 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   city_id  13 non-null     object
#  1   city     13 non-null     object
# dtypes: object(2)
# memory usage: 336.0+ bytes
#                                               city_id           city
# 0   0013c01fe0d094209b8bd3d23b8f96dbabcd01ddd2a039...      Amsterdam
# 1   1e73b1647343b286269d517e6f07e6e07ccef10cd7b785...         Zurich
# 2   2bd25cd960aba8b706e2b67f2bb38b750ee5384b0e9883...      Las Vegas
# 3   5a59ef2e40c5f89adb8c0c6ad0a8019b0e252fff530cf2...  New York City
# 4   5dd272b4f316b776a7b8e3d0894b37e1e42be3d5d3b204...          Paris
# 5   68371d5bdaab31b5cbc25fbf94b8f9c1238294fc50e715...       Tel Aviv
# 6   6c425048aa7badd9d84615bd8620ca1864efd81cfdb69d...          Dubai
# 7   89c7286890f7347ab235234e74d406596a127ae3679042...       Kimberly
# ...

# %%
#vemos cómo son y la información que trae cada tabala- esta es de clarity

di_clarity.info()
di_clarity
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8 entries, 0 to 7
# Data columns (total 2 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   clarity_id  8 non-null      object
#  1   clarity     8 non-null      object
# dtypes: object(2)
# memory usage: 256.0+ bytes
#                                           clarity_id clarity
# 0  03c358cbd92e83278fd523f58dc6a9b4b198d00728af65...     SI2
# 1  3f9db06236e9719b61c826b612b882fa702ec81574e44c...    VVS2
# 2  66686ae1f0c9c400ba32dc600a34ff0aa173395bcbc2d8...    VVS1
# 3  7020fd7aaf1656dea5c0c0c3d4bb5a28ebf6243fba95d3...      IF
# 4  bd4f4a250da88f87729febc739ae97f439a14f9d38f0e3...     SI1
# 5  c2818bc4e5ec4ae4a357a0df6fed73652e169ec676f7d4...      I1
# 6  ef736c1f91cd1900c3d9cde925b1bf4f013adc0211a9ee...     VS1
# 7  f0b2a1d0db08cc64f85d74f1d15c2191e0e49039f4d8f2...     VS2

# %%
#vemos cómo son y la información que trae cada tabala- esta es de los colores de los diamantes

di_color.info()
di_color
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7 entries, 0 to 6
# Data columns (total 2 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   color_id  7 non-null      object
#  1   color     7 non-null      object
# dtypes: object(2)
# memory usage: 240.0+ bytes
#                                             color_id color
# 0  333e0a1e27815d0ceee55c473fe3dc93d56c63e3bee2b3...     G
# 1  3f39d5c348e5b79d06e842c114e6cc571583bbf44e4b0e...     D
# 2  44bd7ae60f478fae1061e11a7739f4b94d1daf917982d3...     H
# 3  6da43b944e494e885e69af021f93c6d9331c78aa228084...     J
# 4  a83dd0ccbffe39d071cc317ddf6e97f5c6b1c87af91919...     I
# 5  a9f51566bd6705f7ea6ad54bb9deb449f795582d6529a0...     E
# 6  f67ab10ad4e4c53121b6a5fe4da9c10ddee905b978d378...     F

# %%
#vemos cómo son y la información que trae cada tabala- esta es la del tipo de corte

di_cut.info()
di_cut
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5 entries, 0 to 4
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   cut_id  5 non-null      object
#  1   cut     5 non-null      object
# dtypes: object(2)
# memory usage: 208.0+ bytes
#                                               cut_id        cut
# 0  388655e25e91872329272fc10128ef5354b3b19a05d7e8...  Very Good
# 1  4e3cfaa334cbafb57a399a98fad8d3812ece460018f457...      Ideal
# 2  c939327ca16dcf97ca32521d8b834bf1de16573d21deda...       Good
# 3  de88c121a82a06352bf1aaceba20578356408a334ba046...    Premium
# 4  f7b19afcde965ea4942b878d266f89f8ba9a5a833e60f7...       Fair

# %%
#vemos cómo son y la información que trae cada tabala- esta es de las dimensiones
di_dime.info()
di_dime
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 40455 entries, 0 to 40454
# Data columns (total 6 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   index_id  40455 non-null  object
#  1   depth     40455 non-null  float64
#  2   table     40455 non-null  float64
#  3   x         40455 non-null  float64
#  4   y         40455 non-null  float64
#  5   z         40455 non-null  float64
# dtypes: float64(5), object(1)
# memory usage: 1.9+ MB
#                                                 index_id  depth  table     x  \
# 0      5feceb66ffc86f38d952786c6d696c79c2dbc239dd4e91...   62.4   58.0  6.83
# 1      6b86b273ff34fce19d6b804eff5a3f5747ada4eaa22f1d...   63.0   57.0  4.35
# 2      d4735e3a265e16eee03f59718b9b5d03019c07d8b6c51f...   65.5   55.0  5.62
# 3      4e07408562bedb8b60ce05c1decfe3ad16b72230967de0...   63.8   56.0  4.68
# 4      4b227777d4dd1fc61c6f884f48641d02b4d121d3fd328c...   60.5   59.0  6.55
# ...

# %%
#vemos cómo son y la información que trae cada tabala- esta es de las proporciones

di_prop.info()
di_prop
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 40455 entries, 0 to 40454
# Data columns (total 4 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   index_id    40455 non-null  object
#  1   cut_id      40455 non-null  object
#  2   color_id    40455 non-null  object
#  3   clarity_id  40455 non-null  object
# dtypes: object(4)
# memory usage: 1.2+ MB
#                                                 index_id  \
# 0      5feceb66ffc86f38d952786c6d696c79c2dbc239dd4e91...
# 1      6b86b273ff34fce19d6b804eff5a3f5747ada4eaa22f1d...
# 2      d4735e3a265e16eee03f59718b9b5d03019c07d8b6c51f...
# 3      4e07408562bedb8b60ce05c1decfe3ad16b72230967de0...
# 4      4b227777d4dd1fc61c6f884f48641d02b4d121d3fd328c...
# ...                                                  ...
# 40450  f0bc79169405ebeb24e308055156b946ffd819db9b4f75...
# 40451  339916a23bf22b052b54cb2a9b36ee8418c1c68b46acad...
# ...

# %%
#vemos cómo son y la información que trae cada tabala- esta es de las transacciones

di_trans.info()
di_trans
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 40455 entries, 0 to 40454
# Data columns (total 4 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   index_id  40455 non-null  object
#  1   price     40455 non-null  int64
#  2   city_id   40455 non-null  object
#  3   carat     40455 non-null  float64
# dtypes: float64(1), int64(1), object(2)
# memory usage: 1.2+ MB
#                                                 index_id  price  \
# 0      5feceb66ffc86f38d952786c6d696c79c2dbc239dd4e91...   4268
# 1      6b86b273ff34fce19d6b804eff5a3f5747ada4eaa22f1d...    505
# 2      d4735e3a265e16eee03f59718b9b5d03019c07d8b6c51f...   2686
# 3      4e07408562bedb8b60ce05c1decfe3ad16b72230967de0...    738
# 4      4b227777d4dd1fc61c6f884f48641d02b4d121d3fd328c...   4882
# ...                                                  ...    ...
# 40450  f0bc79169405ebeb24e308055156b946ffd819db9b4f75...  10070
# ...

# %% [markdown]
# ### Cruce de tablas

# %%
#concateno las tres tablas últimas que tienen el mismo número de rows 

df_concat = pd.concat([di_trans, di_dime, di_prop, ], ignore_index=False, axis=1)

# %%
df_concat
# Out:
#                                                 index_id  price  \
# 0      5feceb66ffc86f38d952786c6d696c79c2dbc239dd4e91...   4268
# 1      6b86b273ff34fce19d6b804eff5a3f5747ada4eaa22f1d...    505
# 2      d4735e3a265e16eee03f59718b9b5d03019c07d8b6c51f...   2686
# 3      4e07408562bedb8b60ce05c1decfe3ad16b72230967de0...    738
# 4      4b227777d4dd1fc61c6f884f48641d02b4d121d3fd328c...   4882
# ...                                                  ...    ...
# 40450  f0bc79169405ebeb24e308055156b946ffd819db9b4f75...  10070
# 40451  339916a23bf22b052b54cb2a9b36ee8418c1c68b46acad...  12615
# 40452  46957922b99954654c1deb8d854c3f069bf118b2ce9415...   5457
# 40453  9d733392d362d5c6f1d9b9659b601c7d4b5a1c1c8df579...    456
# 40454  a02744a70faa594d240b067f21fcc23a8d17cd1098a9fb...   6232
#
#                                                  city_id  carat  \
# 0      89c7286890f7347ab235234e74d406596a127ae3679042...   1.21
# 1      ca3aa21a5b70c3e88cc6336682c8c7da928a0c66a5ead4...   0.32
# ...

# %%
#ahora toca juntar el resto de las tablas para poder empezar mergearlas con la tabla creada arriba df_concat(la que hemos concatenado)

# %%
#jutnto la de las ciudades con la df_concat

df_join1 = [df_concat, di_city]
df_city = ft.reduce(lambda left, right: pd.merge(left, right, on='city_id'), df_join1)
df_city
# Out:
#                                                 index_id  price  \
# 0      5feceb66ffc86f38d952786c6d696c79c2dbc239dd4e91...   4268
# 1      4fc82b26aecb47d2868c4efbe3581732a3e7cbcc6c2efb...   4284
# 2      e629fa6598d732768f7c726b4b621285f9c3b85303900a...   6006
# 3      4523540f1504cd17100c4835e85b7eefd49911580f8eff...    983
# 4      9400f1b21cb527d7fa3d3eabba93557a18ebe7a2ca4e47...  11078
# ...                                                  ...    ...
# 40450  f4669b5848b66564f2317866860f9334ac63f29de3ed45...    921
# 40451  9185c0199efc6aea5b4a97414cd297ead29ad55edec2a7...    540
# 40452  fbed8c8d9adc6a3004f597f06166a4b2f4ad8ad948ee87...   7092
# 40453  1726e8e229489b353e6007fac1dfffb5300a96bf6166cf...   3710
# 40454  9d733392d362d5c6f1d9b9659b601c7d4b5a1c1c8df579...    456
#
#                                                  city_id  carat  \
# 0      89c7286890f7347ab235234e74d406596a127ae3679042...   1.21
# 1      89c7286890f7347ab235234e74d406596a127ae3679042...   1.02
# ...

# %%
#junto la de la df_city con la de clarity


df_join2 = [df_city, di_clarity]
df_clarity = ft.reduce(lambda left, right: pd.merge(left, right, on='clarity_id'), df_join2)
df_clarity
# Out:
#                                                 index_id  price  \
# 0      5feceb66ffc86f38d952786c6d696c79c2dbc239dd4e91...   4268
# 1      4523540f1504cd17100c4835e85b7eefd49911580f8eff...    983
# 2      f5ca38f748a1d6eaf726b8a42fb575c3c71f1864a81433...  11177
# 3      2858dcd1057d3eae7f7d5f782167e24b61153c01551450...   1549
# 4      05ada863a4cf9660fd8c68e2295f1d35b2264815f5b605...   2671
# ...                                                  ...    ...
# 40450  08b8747cf8808b5969f1f00356925723d7da69b644b160...   2721
# 40451  b23817d57f94155839c28c035af4beec4f9ff547599c09...   1337
# 40452  e09a3b3eef1e3a664f3fddbdf92208d8223db888f8151e...   3981
# 40453  d739479786f64801f266489c09214d1f65aeefe7bc8795...    514
# 40454  39f0ab87faa547b2194fd6ed05b1bb35a64dc0d4c9ec52...    581
#
#                                                  city_id  carat  \
# 0      89c7286890f7347ab235234e74d406596a127ae3679042...   1.21
# 1      89c7286890f7347ab235234e74d406596a127ae3679042...   0.38
# ...

# %%
#junto la df_clarity con la de color

df_join3 = [df_clarity, di_color]
df_color = ft.reduce(lambda left, right: pd.merge(left, right, on='color_id'), df_join3)
df_color
# Out:
#                                                 index_id  price  \
# 0      5feceb66ffc86f38d952786c6d696c79c2dbc239dd4e91...   4268
# 1      ed053874ca199cc53e11c9f4aeaeccd07da652d1c19e3c...   3215
# 2      248aa2bdd0032920ac9e5f6ad36c350549da067efeaf7b...   4839
# 3      72b31cf00f8ab3967588fad4a32f61622cb162f9b7bc2c...    368
# 4      bc805497f86694cef2e1cf6df62989cb818f69a80f4fb1...  13542
# ...                                                  ...    ...
# 40450  5eb1d62955a51a5ce396a89a9f2c111ef2df468b5450d7...   9897
# 40451  8c8c8a435cae6ea17cb4ea2d8e8a25e7db1c765feeb2ae...    548
# 40452  c564f3382889ba53b314960a2a53d414e082ffc997960c...    814
# 40453  2cf5ed625832119319d1e63d0aebd4fe62825eda8cdf0e...   1013
# 40454  b23817d57f94155839c28c035af4beec4f9ff547599c09...   1337
#
#                                                  city_id  carat  \
# 0      89c7286890f7347ab235234e74d406596a127ae3679042...   1.21
# 1      89c7286890f7347ab235234e74d406596a127ae3679042...   0.92
# ...

# %%
# y finalmente junto la df_color con la de cut, con esta acabaríamos de juntarlas todas

df_join4 = [df_color, di_cut]
df_cut = ft.reduce(lambda left, right: pd.merge(left, right, on='cut_id'), df_join4)
df_cut
# Out:
#                                                 index_id  price  \
# 0      5feceb66ffc86f38d952786c6d696c79c2dbc239dd4e91...   4268
# 1      248aa2bdd0032920ac9e5f6ad36c350549da067efeaf7b...   4839
# 2      72b31cf00f8ab3967588fad4a32f61622cb162f9b7bc2c...    368
# 3      98c53df687f2e9b94da80eef5b9049f1fac456b4c41c80...   5053
# 4      5dfe43a321c6834c7de273c73aeadc705d919a5869e0f5...   3593
# ...                                                  ...    ...
# 40450  2e06d9b9fb5a84f3e7cc6f4ec05030c271772586527532...    586
# 40451  8c0906fd5efd19b24aa04cb58ff5d90de07a4507ab1620...   5430
# 40452  9bbe997bfd8f696de7cd7c474dce9f4ce4d1f5df28f18b...   1705
# 40453  99c6a18e1b9cb1061de4826d1f6ccaf96d4de1126034a5...   5551
# 40454  e83f125b8f31fc57c87032f7c67df89883454a2df041f0...   2079
#
#                                                  city_id  carat  \
# 0      89c7286890f7347ab235234e74d406596a127ae3679042...   1.21
# 1      89c7286890f7347ab235234e74d406596a127ae3679042...   1.20
# ...

# %%
df_cut
# Out:
#                                                 index_id  price  \
# 0      5feceb66ffc86f38d952786c6d696c79c2dbc239dd4e91...   4268
# 1      248aa2bdd0032920ac9e5f6ad36c350549da067efeaf7b...   4839
# 2      72b31cf00f8ab3967588fad4a32f61622cb162f9b7bc2c...    368
# 3      98c53df687f2e9b94da80eef5b9049f1fac456b4c41c80...   5053
# 4      5dfe43a321c6834c7de273c73aeadc705d919a5869e0f5...   3593
# ...                                                  ...    ...
# 40450  2e06d9b9fb5a84f3e7cc6f4ec05030c271772586527532...    586
# 40451  8c0906fd5efd19b24aa04cb58ff5d90de07a4507ab1620...   5430
# 40452  9bbe997bfd8f696de7cd7c474dce9f4ce4d1f5df28f18b...   1705
# 40453  99c6a18e1b9cb1061de4826d1f6ccaf96d4de1126034a5...   5551
# 40454  e83f125b8f31fc57c87032f7c67df89883454a2df041f0...   2079
#
#                                                  city_id  carat  \
# 0      89c7286890f7347ab235234e74d406596a127ae3679042...   1.21
# 1      89c7286890f7347ab235234e74d406596a127ae3679042...   1.20
# ...

# %%
df_cut.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 40455 entries, 0 to 40454
# Data columns (total 18 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   index_id    40455 non-null  object
#  1   price       40455 non-null  int64
#  2   city_id     40455 non-null  object
#  3   carat       40455 non-null  float64
#  4   index_id    40455 non-null  object
#  5   depth       40455 non-null  float64
#  6   table       40455 non-null  float64
#  7   x           40455 non-null  float64
#  8   y           40455 non-null  float64
#  9   z           40455 non-null  float64
#  10  index_id    40455 non-null  object
#  11  cut_id      40455 non-null  object
#  12  color_id    40455 non-null  object
#  13  clarity_id  40455 non-null  object
#  14  city        40455 non-null  object
#  15  clarity     40455 non-null  object
#  16  color       40455 non-null  object
#  17  cut         40455 non-null  object
# ...

# %%
#quitamos las columnas duplicadas como es el index_id
df = df_cut.T.drop_duplicates().T
df
# Out:
#                                                 index_id price  \
# 0      5feceb66ffc86f38d952786c6d696c79c2dbc239dd4e91...  4268
# 1      248aa2bdd0032920ac9e5f6ad36c350549da067efeaf7b...  4839
# 2      72b31cf00f8ab3967588fad4a32f61622cb162f9b7bc2c...   368
# 3      98c53df687f2e9b94da80eef5b9049f1fac456b4c41c80...  5053
# 4      5dfe43a321c6834c7de273c73aeadc705d919a5869e0f5...  3593
# ...                                                  ...   ...
# 40450  2e06d9b9fb5a84f3e7cc6f4ec05030c271772586527532...   586
# 40451  8c0906fd5efd19b24aa04cb58ff5d90de07a4507ab1620...  5430
# 40452  9bbe997bfd8f696de7cd7c474dce9f4ce4d1f5df28f18b...  1705
# 40453  99c6a18e1b9cb1061de4826d1f6ccaf96d4de1126034a5...  5551
# 40454  e83f125b8f31fc57c87032f7c67df89883454a2df041f0...  2079
#
#                                                  city_id carat depth table  \
# 0      89c7286890f7347ab235234e74d406596a127ae3679042...  1.21  62.4  58.0
# ...

# %%
df.columns
# Out:
# Index(['index_id', 'price', 'city_id', 'carat', 'depth', 'table', 'x', 'y',
#        'z', 'cut_id', 'color_id', 'clarity_id', 'city', 'clarity', 'color',
#        'cut'],
#       dtype='object')

# %%
df.drop(columns=["city_id", "cut_id", "clarity_id", "color_id", "index_id"], inplace=True)

# %%
df.isna().sum()
# Out:
# price      0
# carat      0
# depth      0
# table      0
# x          0
# y          0
# z          0
# city       0
# clarity    0
# color      0
# cut        0
# dtype: int64

# %%
df.describe()
# Out:
#         price    carat    depth    table         x         y         z  \
# count   40455  40455.0  40455.0  40455.0  40455.00  40455.00  40455.00
# unique  10378    270.0    175.0    121.0    543.00    539.00    363.00
# top       605      0.3     61.9     56.0      4.37      4.37      2.69
# freq      106   1973.0   1647.0   7477.0    353.00    334.00    581.00
#
#            city clarity  color    cut
# count     40455   40455  40455  40455
# unique       13       8      7      5
# top     Antwerp     SI1      G  Ideal
# freq       5062    9749   8455  16220

# %%
df
# Out:
#       price carat depth table     x     y     z       city clarity color  \
# 0      4268  1.21  62.4  58.0  6.83  6.79  4.25   Kimberly     VS2     J
# 1      4839   1.2  60.8  60.0  6.85  6.89  4.18   Kimberly     VS2     J
# 2       368   0.3  60.6  59.0  4.34  4.38  2.64   Kimberly     VS2     J
# 3      5053   1.2  62.6  57.0   6.8  6.72  4.23   Kimberly     VS2     J
# 4      3593  1.05  59.4  62.0  6.66  6.58  3.93   Kimberly     VS2     J
# ...     ...   ...   ...   ...   ...   ...   ...        ...     ...   ...
# 40450   586   0.3  66.6  54.0  4.14  4.18  2.77      Dubai    VVS2     E
# 40451  5430  0.91  63.1  55.0  6.13   6.0  3.83  Amsterdam    VVS2     E
# 40452  1705  0.49  65.5  58.0  4.91  4.86   3.2  Amsterdam    VVS2     E
# 40453  5551   0.9  58.1  59.0  6.21  6.26  3.62  Amsterdam    VVS2     E
# 40454  2079  0.52  57.2  64.0  5.27  5.36  3.04      Paris    VVS2     E
#
#            cut
# 0      Premium
# 1      Premium
# 2      Premium
# 3      Premium
# ...

# %%
df.query("x==0 or y==0 or z==0")
# Out:
#        price carat depth table     x     y    z       city clarity color  \
# 1741    3696   1.1  63.0  59.0   6.5  6.47  0.0      Dubai     SI2     G
# 1825    3142   1.0  59.1  59.0  6.55  6.48  0.0     Zurich     SI2     G
# 2826   18207  2.02  62.7  53.0  8.02  7.95  0.0   Kimberly     VS2     H
# 3656   17265   2.2  61.2  59.0  8.42  8.37  0.0      Surat     SI1     H
# 3892   12631  2.18  59.4  61.0  8.49  8.45  0.0  Las Vegas     SI2     H
# 3996   18034  2.25  62.8  59.0   0.0   0.0  0.0  Amsterdam     SI2     H
# 4443    3167  1.01  58.1  59.0  6.66   6.6  0.0   Kimberly      I1     H
# 5691    3837  1.01  59.2  58.0   6.5  6.47  0.0  Las Vegas     SI2     F
# 7777   15397  2.25  61.3  58.0  8.52  8.42  0.0    Antwerp     SI1     I
# 11325   5564  1.15  59.2  56.0  6.88  6.83  0.0     Madrid     VS2     G
# 18300   4954  1.07  61.6  56.0   0.0  6.62  0.0  Amsterdam     SI2     F
# 27142  18788   2.8  63.8  58.0   8.9  8.85  0.0      Paris     SI2     G
# ...

# %%
sns.scatterplot(x=df.carat , y=df.price)
# Out:
# <AxesSubplot:xlabel='carat', ylabel='price'>

# %%
print(len(df.query("carat>4")))
print(len(df.query("carat>3")))
print(len(df.query("carat>2")))
# Out:
# 4
# 26
# 1441

# %%
sns.distplot(df.price)
# Out:
# /Users/halimaelbadoui/miniconda3/envs/m3_hi/lib/python3.10/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='price', ylabel='Density'>

# %%
sns.pairplot(df)

# %%
df["clarity"].unique()
# Out:
# array(['VS2', 'SI1', 'SI2', 'VS1', 'VVS1', 'I1', 'IF', 'VVS2'],
#       dtype=object)

# %%
#outliers

# %%
print(len(df.query("carat>4")))
print(len(df.query("carat>3")))
print(len(df.query("carat>2")))
# Out:
# 4
# 26
# 1441

# %%
df.query("carat>4")
# Out:
#        price carat depth table      x      y     z    city clarity color  \
# 582    15223  4.01  62.5  62.0  10.02   9.94  6.24   Surat      I1     J
# 8438   15223  4.01  61.0  61.0  10.14   10.1  6.17   Surat      I1     I
# 39325  18531   4.5  65.8  58.0  10.23  10.16  6.72   Surat      I1     J
# 39765  17329  4.13  64.8  61.0   10.0   9.85  6.43  Zurich      I1     H
#
#            cut
# 582    Premium
# 8438   Premium
# 39325     Fair
# 39765     Fair

# %%
#df.drop(df.query("carat>4").index, inplace=True)- no me sale a cuenta quitarlos
df
# Out:
#       price carat depth table     x     y     z       city clarity color  \
# 0      4268  1.21  62.4  58.0  6.83  6.79  4.25   Kimberly     VS2     J
# 1      4839   1.2  60.8  60.0  6.85  6.89  4.18   Kimberly     VS2     J
# 2       368   0.3  60.6  59.0  4.34  4.38  2.64   Kimberly     VS2     J
# 3      5053   1.2  62.6  57.0   6.8  6.72  4.23   Kimberly     VS2     J
# 4      3593  1.05  59.4  62.0  6.66  6.58  3.93   Kimberly     VS2     J
# ...     ...   ...   ...   ...   ...   ...   ...        ...     ...   ...
# 40450   586   0.3  66.6  54.0  4.14  4.18  2.77      Dubai    VVS2     E
# 40451  5430  0.91  63.1  55.0  6.13   6.0  3.83  Amsterdam    VVS2     E
# 40452  1705  0.49  65.5  58.0  4.91  4.86   3.2  Amsterdam    VVS2     E
# 40453  5551   0.9  58.1  59.0  6.21  6.26  3.62  Amsterdam    VVS2     E
# 40454  2079  0.52  57.2  64.0  5.27  5.36  3.04      Paris    VVS2     E
#
#            cut
# 0      Premium
# 1      Premium
# 2      Premium
# 3      Premium
# ...

# %%
df.query("z>10 or y>10").index
# Out:
# Int64Index([3786, 8438, 39325], dtype='int64')

# %%
df.drop(df.query("z>10 or y>10").index, inplace=True)
df.query("x==0 or y==0 or z==0")
# Out:
#        price carat depth table     x     y    z       city clarity color  \
# 1741    3696   1.1  63.0  59.0   6.5  6.47  0.0      Dubai     SI2     G
# 1825    3142   1.0  59.1  59.0  6.55  6.48  0.0     Zurich     SI2     G
# 2826   18207  2.02  62.7  53.0  8.02  7.95  0.0   Kimberly     VS2     H
# 3656   17265   2.2  61.2  59.0  8.42  8.37  0.0      Surat     SI1     H
# 3892   12631  2.18  59.4  61.0  8.49  8.45  0.0  Las Vegas     SI2     H
# 3996   18034  2.25  62.8  59.0   0.0   0.0  0.0  Amsterdam     SI2     H
# 4443    3167  1.01  58.1  59.0  6.66   6.6  0.0   Kimberly      I1     H
# 5691    3837  1.01  59.2  58.0   6.5  6.47  0.0  Las Vegas     SI2     F
# 7777   15397  2.25  61.3  58.0  8.52  8.42  0.0    Antwerp     SI1     I
# 11325   5564  1.15  59.2  56.0  6.88  6.83  0.0     Madrid     VS2     G
# 18300   4954  1.07  61.6  56.0   0.0  6.62  0.0  Amsterdam     SI2     F
# 27142  18788   2.8  63.8  58.0   8.9  8.85  0.0      Paris     SI2     G
# ...

# %%
df.query("x==0 or y==0 or z==0").index
# Out:
# Int64Index([ 1741,  1825,  2826,  3656,  3892,  3996,  4443,  5691,  7777,
#             11325, 18300, 27142, 27286, 28326, 28376, 39496],
#            dtype='int64')

# %%
df.drop(df.query("x==0 or y==0 or z==0").index, inplace=True)
sns.pairplot(df)

# %%
#df["vol"] = df.x * df.y * df.z
df.head()
# Out:
#   price carat depth table     x     y     z      city clarity color      cut
# 0  4268  1.21  62.4  58.0  6.83  6.79  4.25  Kimberly     VS2     J  Premium
# 1  4839   1.2  60.8  60.0  6.85  6.89  4.18  Kimberly     VS2     J  Premium
# 2   368   0.3  60.6  59.0  4.34  4.38  2.64  Kimberly     VS2     J  Premium
# 3  5053   1.2  62.6  57.0   6.8  6.72  4.23  Kimberly     VS2     J  Premium
# 4  3593  1.05  59.4  62.0  6.66  6.58  3.93  Kimberly     VS2     J  Premium

# %%
#df.drop(["x", "y","z"], axis=1, inplace=True)
df.head()
# Out:
#   price carat depth table     x     y     z      city clarity color      cut
# 0  4268  1.21  62.4  58.0  6.83  6.79  4.25  Kimberly     VS2     J  Premium
# 1  4839   1.2  60.8  60.0  6.85  6.89  4.18  Kimberly     VS2     J  Premium
# 2   368   0.3  60.6  59.0  4.34  4.38  2.64  Kimberly     VS2     J  Premium
# 3  5053   1.2  62.6  57.0   6.8  6.72  4.23  Kimberly     VS2     J  Premium
# 4  3593  1.05  59.4  62.0  6.66  6.58  3.93  Kimberly     VS2     J  Premium

# %%
print(df["cut"].loc[df["cut"]=="Ideal"].count()) #5
print(df["cut"].loc[df["cut"]=="Premium"].count()) #4
print(df["cut"].loc[df["cut"]=="Good"].count()) #2
print(df["cut"].loc[df["cut"]=="Very Good"].count()) #3
print(df["cut"].loc[df["cut"]=="Fair"].count()) #1
# Out:
# 16218
# 10249
# 3659
# 9095
# 1215

# %%
df.cut.replace({"Ideal":5, "Premium":4, "Good":2, "Very Good":3, "Fair":1}, inplace=True)

# %%
df.head()
# Out:
#   price carat depth table     x     y     z      city clarity color  cut
# 0  4268  1.21  62.4  58.0  6.83  6.79  4.25  Kimberly     VS2     J    4
# 1  4839   1.2  60.8  60.0  6.85  6.89  4.18  Kimberly     VS2     J    4
# 2   368   0.3  60.6  59.0  4.34  4.38  2.64  Kimberly     VS2     J    4
# 3  5053   1.2  62.6  57.0   6.8  6.72  4.23  Kimberly     VS2     J    4
# 4  3593  1.05  59.4  62.0  6.66  6.58  3.93  Kimberly     VS2     J    4

# %%
df.color.unique()
# Out:
# array(['J', 'G', 'H', 'F', 'D', 'I', 'E'], dtype=object)

# %%
print(df["color"].loc[df["color"]=='J'].count()) #
print(df["color"].loc[df["color"]=='G'].count())#7
print(df["color"].loc[df["color"]=='H'].count())#
print(df["color"].loc[df["color"]=='F'].count())#
print(df["color"].loc[df["color"]=='D'].count())#
print(df["color"].loc[df["color"]=='I'].count())#
print(df["color"].loc[df["color"]=='E'].count())#6
# Out:
# 2139
# 8449
# 6271
# 7173
# 5049
# 4030
# 7325

# %%
df.color.replace({"E":2, "I":6, "J":7, "H":5, "F":3, "G":4, "D":1}, inplace=True)
df.head()
# Out:
#   price carat depth table     x     y     z      city clarity  color  cut
# 0  4268  1.21  62.4  58.0  6.83  6.79  4.25  Kimberly     VS2      7    4
# 1  4839   1.2  60.8  60.0  6.85  6.89  4.18  Kimberly     VS2      7    4
# 2   368   0.3  60.6  59.0  4.34  4.38  2.64  Kimberly     VS2      7    4
# 3  5053   1.2  62.6  57.0   6.8  6.72  4.23  Kimberly     VS2      7    4
# 4  3593  1.05  59.4  62.0  6.66  6.58  3.93  Kimberly     VS2      7    4

# %%
print(df["clarity"].loc[df["clarity"]=='VS2'].count()) #
print(df["clarity"].loc[df["clarity"]=='SI1'].count())#8
print(df["clarity"].loc[df["clarity"]=='SI2'].count())#
print(df["clarity"].loc[df["clarity"]=='VS1'].count())#
print(df["clarity"].loc[df["clarity"]=='VVS1'].count())#
print(df["clarity"].loc[df["clarity"]=='I1'].count())#
print(df["clarity"].loc[df["clarity"]=='IF'].count())#
print(df["clarity"].loc[df["clarity"]=='VVS2'].count())#

# %%
df.clarity.replace({"SI2":8, "SI1":7, "VS1":6, "VS2":5, "VVS2":4, "VVS1":3, "I1":1, "IF":2}, inplace=True)
df.head()
# Out:
#   price carat depth table     x     y     z      city  clarity  color  cut
# 0  4268  1.21  62.4  58.0  6.83  6.79  4.25  Kimberly        5      7    4
# 1  4839   1.2  60.8  60.0  6.85  6.89  4.18  Kimberly        5      7    4
# 2   368   0.3  60.6  59.0  4.34  4.38  2.64  Kimberly        5      7    4
# 3  5053   1.2  62.6  57.0   6.8  6.72  4.23  Kimberly        5      7    4
# 4  3593  1.05  59.4  62.0  6.66  6.58  3.93  Kimberly        5      7    4

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 40455 entries, 0 to 40454
# Data columns (total 11 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   price    40455 non-null  object
#  1   carat    40455 non-null  object
#  2   depth    40455 non-null  object
#  3   table    40455 non-null  object
#  4   x        40455 non-null  object
#  5   y        40455 non-null  object
#  6   z        40455 non-null  object
#  7   city     40455 non-null  object
#  8   clarity  40455 non-null  int64
#  9   color    40455 non-null  int64
#  10  cut      40455 non-null  int64
# dtypes: int64(3), object(8)
# memory usage: 4.7+ MB

# %%
df[["price", "carat", "depth", "table", "cut", "x", "y", "z"]]= df[["price", "carat", "depth", "table", "cut","x", "y", "z"]].apply(pd.to_numeric)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 40455 entries, 0 to 40454
# Data columns (total 11 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   price    40455 non-null  int64
#  1   carat    40455 non-null  float64
#  2   depth    40455 non-null  float64
#  3   table    40455 non-null  float64
#  4   x        40455 non-null  float64
#  5   y        40455 non-null  float64
#  6   z        40455 non-null  float64
#  7   city     40455 non-null  object
#  8   clarity  40455 non-null  int64
#  9   color    40455 non-null  int64
#  10  cut      40455 non-null  int64
# dtypes: float64(6), int64(4), object(1)
# memory usage: 4.7+ MB

# %%
X = df.drop(['price', "city"], axis=1)
X.head()
# Out:
#    carat  depth  table     x     y     z  clarity  color  cut
# 0   1.21   62.4   58.0  6.83  6.79  4.25        5      7    4
# 1   1.20   60.8   60.0  6.85  6.89  4.18        5      7    4
# 2   0.30   60.6   59.0  4.34  4.38  2.64        5      7    4
# 3   1.20   62.6   57.0  6.80  6.72  4.23        5      7    4
# 4   1.05   59.4   62.0  6.66  6.58  3.93        5      7    4

# %%
y = df["price"]
y.head()
# Out:
# 0    4268
# 1    4839
# 2     368
# 3    5053
# 4    3593
# Name: price, dtype: int64

# %%
#training the model

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=123)

# %%
#minmaxscaler = MinMaxScaler()
#numcols = ['carat','depth','table']

# %%
#X_train[numcols] = minmaxscaler.fit_transform(X_train[numcols])

# %%
#X_train.head()

# %%
#X_test[numcols] = minmaxscaler.transform(X_test[numcols])

# %%
import sklearn.ensemble as se
rf = se.RandomForestRegressor(n_estimators = 1000, random_state=123, max_depth = 64)
rf.fit(X_train, y_train)
# Out:
# RandomForestRegressor(max_depth=64, n_estimators=1000, random_state=123)

# %%
print('R squared of the Random Forest Regressor on training set: {:.2%}'.format(rf.score(X_train, y_train)))
print('R squared of the Random Forest Regressor on test set: {:.2%}'.format(rf.score(X_test, y_test)))
# Out:
# R squared of the Random Forest Regressor on training set: 99.74%
# R squared of the Random Forest Regressor on test set: 98.22%

# %%
y_pred2 = rf.predict(X_test)
sns.scatterplot(x=y_test , y=y_pred2, color="green")
# Out:
# <AxesSubplot:xlabel='price'>

# %%
d = {"true": y_test, "predicted": y_pred2}
df_rf = pd.DataFrame(data=d)
df_rf["diff"] = df_rf["predicted"]-df_rf["true"]
print(df_rf["diff"].mean())
df_rf
# Out:
# 2.921887959529788
#         true    predicted       diff
# 2077    6730   6963.33000  233.33000
# 20101   1963   2011.71300   48.71300
# 27562  15467  14915.62100 -551.37900
# 4744    1753   1943.36500  190.36500
# 19520    872    914.76600   42.76600
# ...      ...          ...        ...
# 7702   16778  16846.06400   68.06400
# 38819    489    505.96900   16.96900
# 39992   1158   1084.01600  -73.98400
# 13144    624    580.74300  -43.25700
# 33716   2558   2632.48115   74.48115
#
# [8091 rows x 3 columns]

# %%
mean_squared_error(y_test, y_pred2)
# Out:
# 285140.4876048407

# %%
rmse = mean_squared_error(y_test, y_pred2, squared=False)
rmse
# Out:
# 533.985475087891

# %%
# %%time

scores = cross_val_score(rf, 
                         X, 
                         y, 
                         scoring='neg_root_mean_squared_error', 
                         cv=5,
                         n_jobs=1)

print(type(rf), '\n')
print(scores, '\n')
print(np.mean(-scores), '\n')
# Out:
# <class 'sklearn.ensemble._forest.RandomForestRegressor'>
#
# [-731.56397112 -595.59493846 -513.71728387 -539.06630783 -564.2778092 ]
#
# 588.8440620955691
#
# CPU times: user 6min 3s, sys: 7.64 s, total: 6min 11s
# Wall time: 6min 21s

# %%
# %%time

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=123)

model_rmse = RandomForestRegressor(n_estimators = 1000, random_state=123, max_depth = 64)
#model_rmse = GradientBoostingRegressor(random_state = 42)

model_rmse.fit(X_train, y_train)
y_pred = model_rmse.predict(X_test)

hyperparameters = model_rmse.get_params()

rmse = mean_squared_error(y_test, y_pred)**0.5

print(type(model_rmse), '\n')
print(rmse, '\n')
# Out:
# <class 'sklearn.ensemble._forest.RandomForestRegressor'>
#
# 533.985475087891
#
# CPU times: user 1min 14s, sys: 1.68 s, total: 1min 15s
# Wall time: 1min 17s

# %%
param_grid = {'n_estimators': [512, 1024, 2000],
              'max_depth': [32, 64, 128]}

# %%
grid_search = GridSearchCV(rf,
                           param_grid,
                           cv=5,
                           verbose=3,
                           scoring='neg_root_mean_squared_error',
                           n_jobs=-1)

# %%
# %%time

grid_search.fit(X,y)

print('\n')
print('Best hyperparameters: ', grid_search.best_params_, '\n')
print('Best score: ', -grid_search.best_score_, '\n')
# Out:
# Fitting 5 folds for each of 9 candidates, totalling 45 fits
# [CV 3/5] END .max_depth=32, n_estimators=512;, score=-519.344 total time=  57.9s
# [CV 3/5] END max_depth=32, n_estimators=2000;, score=-518.743 total time= 4.1min
# [CV 1/5] END max_depth=64, n_estimators=2000;, score=-722.382 total time= 4.0min
# [CV 4/5] END max_depth=128, n_estimators=1024;, score=-551.604 total time= 1.9min
# [CV 2/5] END max_depth=32, n_estimators=1024;, score=-596.660 total time= 1.9min
# [CV 5/5] END max_depth=32, n_estimators=2000;, score=-581.721 total time= 3.7min
# [CV 2/5] END max_depth=64, n_estimators=2000;, score=-596.944 total time= 4.2min
# [CV 5/5] END max_depth=128, n_estimators=1024;, score=-581.371 total time= 1.8min
#
#
# Best hyperparameters:  {'max_depth': 32, 'n_estimators': 1024}
#
# Best score:  594.1423307999572
#
# CPU times: user 1min 34s, sys: 1.23 s, total: 1min 35s
# Wall time: 17min 9s
# [CV 4/5] END .max_depth=32, n_estimators=512;, score=-551.387 total time=  57.6s
# ...

# %%
#ahora testeamos

# %%
test_d = pd.read_csv("./data/diamonds_test.csv")
test_d.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13485 entries, 0 to 13484
# Data columns (total 11 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   id       13485 non-null  int64
#  1   carat    13485 non-null  float64
#  2   cut      13485 non-null  object
#  3   color    13485 non-null  object
#  4   clarity  13485 non-null  object
#  5   depth    13485 non-null  float64
#  6   table    13485 non-null  float64
#  7   x        13485 non-null  float64
#  8   y        13485 non-null  float64
#  9   z        13485 non-null  float64
#  10  city     13485 non-null  object
# dtypes: float64(6), int64(1), object(4)
# memory usage: 1.1+ MB

# %%
test_d.head()
# Out:
#    id  carat        cut color clarity  depth  table     x     y     z  \
# 0   0   0.79  Very Good     F     SI1   62.7   60.0  5.82  5.89  3.67
# 1   1   1.20      Ideal     J     VS1   61.0   57.0  6.81  6.89  4.18
# 2   2   1.57    Premium     H     SI1   62.2   61.0  7.38  7.32  4.57
# 3   3   0.90  Very Good     F     SI1   63.8   54.0  6.09  6.13  3.90
# 4   4   0.50  Very Good     F     VS1   62.9   58.0  5.05  5.09  3.19
#
#         city
# 0  Amsterdam
# 1      Surat
# 2   Kimberly
# 3   Kimberly
# 4  Amsterdam

# %%
#test_d["vol"] = test_d.x * test_d.y * test_d.z
#test_d.head()

# %%
#test_d.drop(["x", "y", "z"], axis=1,inplace=True)

# %%
test_d.cut.replace({"Ideal":5, "Premium":4, "Good":2, "Very Good":3, "Fair":1}, inplace=True)

# %%
test_d.color.replace({"E":2, "I":6, "J":7, "H":5, "F":3, "G":4, "D":1}, inplace=True)

test_d.clarity.replace({"SI2":8, "SI1":7, "VS1":6, "VS2":5, "VVS2":4, "VVS1":3, "I1":1, "IF":2}, inplace=True)

# %%
test_d.head()
# Out:
#    id  carat  cut  color  clarity  depth  table     x     y     z       city
# 0   0   0.79    3      3        7   62.7   60.0  5.82  5.89  3.67  Amsterdam
# 1   1   1.20    5      7        6   61.0   57.0  6.81  6.89  4.18      Surat
# 2   2   1.57    4      5        7   62.2   61.0  7.38  7.32  4.57   Kimberly
# 3   3   0.90    3      3        7   63.8   54.0  6.09  6.13  3.90   Kimberly
# 4   4   0.50    3      3        6   62.9   58.0  5.05  5.09  3.19  Amsterdam

# %%
test_d_1 = pd.DataFrame(test_d, columns=["carat", "depth", "table", "x", "y", "z", "clarity", "color", "cut"])
test_d_1
# Out:
#        carat  depth  table     x     y     z  clarity  color  cut
# 0       0.79   62.7   60.0  5.82  5.89  3.67        7      3    3
# 1       1.20   61.0   57.0  6.81  6.89  4.18        6      7    5
# 2       1.57   62.2   61.0  7.38  7.32  4.57        7      5    4
# 3       0.90   63.8   54.0  6.09  6.13  3.90        7      3    3
# 4       0.50   62.9   58.0  5.05  5.09  3.19        6      3    3
# ...      ...    ...    ...   ...   ...   ...      ...    ...  ...
# 13480   0.57   61.9   56.0  5.35  5.32  3.30        7      2    5
# 13481   0.71   62.2   55.0  5.71  5.73  3.56        5      6    5
# 13482   0.70   61.6   55.0  5.75  5.71  3.53        6      3    5
# 13483   0.70   58.8   57.0  5.85  5.89  3.45        8      3    3
# 13484   0.40   62.4   55.0  4.70  4.73  2.94        4      6    5
#
# [13485 rows x 9 columns]

# %%
prediction = rf.predict(test_d_1)
prediction
# Out:
# array([3063.109, 5365.292, 9669.443, ..., 2984.163, 2232.74 ,  869.799])

# %%
df_5= pd.DataFrame(prediction).rename(columns = {0:'price'})
df_5
# Out:
#           price
# 0      3063.109
# 1      5365.292
# 2      9669.443
# 3      4072.275
# 4      1728.666
# ...         ...
# 13480  1840.206
# 13481  2317.257
# 13482  2984.163
# 13483  2232.740
# 13484   869.799
#
# [13485 rows x 1 columns]

# %%
df_5.index.names=["id"]

# %%
df_5 = df_5.reset_index()
df_5
# Out:
#           id     price
# 0          0  3063.109
# 1          1  5365.292
# 2          2  9669.443
# 3          3  4072.275
# 4          4  1728.666
# ...      ...       ...
# 13480  13480  1840.206
# 13481  13481  2317.257
# 13482  13482  2984.163
# 13483  13483  2232.740
# 13484  13484   869.799
#
# [13485 rows x 2 columns]

# %%
diamonds = df_5.to_csv("diamonds_0_88.csv", index=False)

# %%
r_df_05= pd.read_csv("diamonds_0_82.csv")
r_df_06= pd.read_csv("diamonds_0_88.csv")

# %%
r_df_05
# Out:
#           id     price
# 0          0  3107.955
# 1          1  5405.579
# 2          2  9739.469
# 3          3  4197.544
# 4          4  1678.889
# ...      ...       ...
# 13480  13480  1683.903
# 13481  13481  2319.279
# 13482  13482  3001.640
# 13483  13483  2220.160
# 13484  13484   862.926
#
# [13485 rows x 2 columns]

# %%
r_df_06
# Out:
#           id     price
# 0          0  3063.109
# 1          1  5365.292
# 2          2  9669.443
# 3          3  4072.275
# 4          4  1728.666
# ...      ...       ...
# 13480  13480  1840.206
# 13481  13481  2317.257
# 13482  13482  2984.163
# 13483  13483  2232.740
# 13484  13484   869.799
#
# [13485 rows x 2 columns]
